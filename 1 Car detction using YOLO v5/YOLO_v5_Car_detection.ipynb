# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt comet_ml  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-421-g79c4c31d Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.6/112.6 GB disk)

# %%
# !unzip -q ../train_data.zip -d ../

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python train.py --img 640 --batch 4 --epochs 100 --data custom_data.yaml --weights yolov5s.pt --cache
# Out:
# 2025-06-14 04:35:13.610986: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749875713.866905    2449 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749875713.940049    2449 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source ../video.mp4
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=../video.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-421-g79c4c31d Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/481) /content/video.mp4: 640x384 1 car, 28.4ms
# video 1/1 (2/481) /content/video.mp4: 640x384 3 cars, 7.5ms
# video 1/1 (3/481) /content/video.mp4: 640x384 3 cars, 7.4ms
# video 1/1 (4/481) /content/video.mp4: 640x384 3 cars, 7.4ms
# video 1/1 (5/481) /content/video.mp4: 640x384 2 cars, 7.4ms
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/last.pt --img 640 --conf 0.25 --source ../video.mp4
# Out:
# detect: weights=['runs/train/exp/weights/last.pt'], source=../video.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-421-g79c4c31d Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/481) /content/video.mp4: 640x384 1 car, 28.5ms
# video 1/1 (2/481) /content/video.mp4: 640x384 1 car, 7.5ms
# video 1/1 (3/481) /content/video.mp4: 640x384 3 cars, 7.4ms
# video 1/1 (4/481) /content/video.mp4: 640x384 2 cars, 7.4ms
# video 1/1 (5/481) /content/video.mp4: 640x384 1 car, 7.4ms
# ...
